# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-617f1d35-b893-4bcb-b235-64151c205a6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-617f1d35-b893-4bcb-b235-64151c205a6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-53454514-d551-46ee-bf8a-12dbdfb0837d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53454514-d551-46ee-bf8a-12dbdfb0837d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ccaf5c94-bccc-4866-9d80-99653dd5f0cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccaf5c94-bccc-4866-9d80-99653dd5f0cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-de94a43d-0a2e-4b20-858e-16f8d78bd96f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de94a43d-0a2e-4b20-858e-16f8d78bd96f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
customers = pd.read_csv("Customer_Details.csv")

# %%
customers.head()
# Out:
#    CustomerID  SignupDate  Gender AgeBand               Segment    Tier  \
# 0      500001  2022-03-20    Male   35-44    Young Professional  Tier-1
# 1      500002  2021-10-19    Male   18-24               Student  Tier-1
# 2      500003  2023-10-10  Female     45+          Family Buyer  Tier-3
# 3      500004  2021-05-24  Female   18-24                 Gamer  Tier-2
# 4      500005  2020-06-01  Female   25-34  Working Professional  Tier-3
#
#         City          State   Region          PreferredChannel  ActivityWeight
# 0  Hyderabad      Telangana    South                  Flipkart          8.3345
# 1       Pune    Maharashtra     West                  Flipkart          0.6440
# 2     Raipur   Chhattisgarh  Central              Amazon India          0.3899
# 3     Nagpur    Maharashtra     West              Amazon India          0.4533
# 4   Varanasi  Uttar Pradesh    North  Local Multi-brand Retail          0.8344

# %%
customers.shape
# Out:
# (150000, 11)

# %%
customers.isnull().sum()
# Out:
# CustomerID          0
# SignupDate          0
# Gender              0
# AgeBand             0
# Segment             0
# Tier                0
# City                0
# State               0
# Region              0
# PreferredChannel    0
# ActivityWeight      0
# dtype: int64

# %%
(customers.isnull().sum() / len(customers)) * 100
# Out:
# CustomerID          0.0
# SignupDate          0.0
# Gender              0.0
# AgeBand             0.0
# Segment             0.0
# Tier                0.0
# City                0.0
# State               0.0
# Region              0.0
# PreferredChannel    0.0
# ActivityWeight      0.0
# dtype: float64

# %%
customers.apply(lambda x: x.astype(str).str.strip().eq("").sum())
# Out:
# CustomerID          0
# SignupDate          0
# Gender              0
# AgeBand             0
# Segment             0
# Tier                0
# City                0
# State               0
# Region              0
# PreferredChannel    0
# ActivityWeight      0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["CustomerID"].nunique()
# Out:
# 150000

# %%
len(customers)
# Out:
# 150000

# %%
customers.dtypes
# Out:
# CustomerID            int64
# SignupDate           object
# Gender               object
# AgeBand              object
# Segment              object
# Tier                 object
# City                 object
# State                object
# Region               object
# PreferredChannel     object
# ActivityWeight      float64
# dtype: object

# %%
customers["SignupDate"] = pd.to_datetime(customers["SignupDate"])

# %%
customers.dtypes
# Out:
# CustomerID                   int64
# SignupDate          datetime64[ns]
# Gender                      object
# AgeBand                     object
# Segment                     object
# Tier                        object
# City                        object
# State                       object
# Region                      object
# PreferredChannel            object
# ActivityWeight             float64
# dtype: object

# %%
text_columns = customers.select_dtypes(include="object").columns

customers[text_columns] = customers[text_columns].apply(
    lambda x: x.str.strip()
)

# %%
customers[text_columns] = customers[text_columns].apply(
    lambda x: x.str.replace(r"\s+", " ", regex=True)
)

# %%
customers["AgeBand"].describe()
# Out:
# count     150000
# unique         4
# top        25-34
# freq       52708
# Name: AgeBand, dtype: object

# %%
customers["SignupDate"].min(), customers["SignupDate"].max()
# Out:
# (Timestamp('2019-01-01 00:00:00'), Timestamp('2024-12-31 00:00:00'))

# %%
customers[customers["SignupDate"] > pd.Timestamp.today()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, SignupDate, Gender, AgeBand, Segment, Tier, City, State, Region, PreferredChannel, ActivityWeight]
# Index: []

# %%
customers["Gender"].value_counts(dropna=False)
# Out:
# Gender
# Male      93179
# Female    56821
# Name: count, dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CustomerID        150000 non-null  int64
#  1   SignupDate        150000 non-null  datetime64[ns]
#  2   Gender            150000 non-null  object
#  3   AgeBand           150000 non-null  object
#  4   Segment           150000 non-null  object
#  5   Tier              150000 non-null  object
#  6   City              150000 non-null  object
#  7   State             150000 non-null  object
#  8   Region            150000 non-null  object
#  9   PreferredChannel  150000 non-null  object
#  10  ActivityWeight    150000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 12.6+ MB

# %%
customers.describe(include="all")
# Out:
#            CustomerID                  SignupDate  Gender AgeBand  \
# count   150000.000000                      150000  150000  150000
# unique            NaN                         NaN       2       4
# top               NaN                         NaN    Male   25-34
# freq              NaN                         NaN   93179   52708
# mean    575000.500000  2022-01-01 05:14:30.336000     NaN     NaN
# min     500001.000000         2019-01-01 00:00:00     NaN     NaN
# 25%     537500.750000         2020-07-01 00:00:00     NaN     NaN
# 50%     575000.500000         2022-01-01 00:00:00     NaN     NaN
# 75%     612500.250000         2023-07-05 00:00:00     NaN     NaN
# max     650000.000000         2024-12-31 00:00:00     NaN     NaN
# std      43301.414527                         NaN     NaN     NaN
#
#                    Segment    Tier    City        State  Region  \
# count               150000  150000  150000       150000  150000
# ...

# %%
customers.head()
# Out:
#    CustomerID SignupDate  Gender AgeBand               Segment    Tier  \
# 0      500001 2022-03-20    Male   35-44    Young Professional  Tier-1
# 1      500002 2021-10-19    Male   18-24               Student  Tier-1
# 2      500003 2023-10-10  Female     45+          Family Buyer  Tier-3
# 3      500004 2021-05-24  Female   18-24                 Gamer  Tier-2
# 4      500005 2020-06-01  Female   25-34  Working Professional  Tier-3
#
#         City          State   Region          PreferredChannel  ActivityWeight
# 0  Hyderabad      Telangana    South                  Flipkart          8.3345
# 1       Pune    Maharashtra     West                  Flipkart          0.6440
# 2     Raipur   Chhattisgarh  Central              Amazon India          0.3899
# 3     Nagpur    Maharashtra     West              Amazon India          0.4533
# 4   Varanasi  Uttar Pradesh    North  Local Multi-brand Retail          0.8344

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["CustomerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["CustomerID"].nunique()
# Out:
# 150000

# %%
text_cols = customers.select_dtypes(include="object").columns

for col in text_cols:
    print(f"\n{col}")
    print(customers[col].value_counts())
# Out:
# Gender
# Gender
# Male      93179
# Female    56821
# Name: count, dtype: int64
#
# AgeBand
# AgeBand
# 25-34    52708
# 18-24    50575
# 35-44    27203
# 45+      19514
# Name: count, dtype: int64
#
# Segment
# Segment
# Young Professional      46251
# Student                 35755
# Working Professional    24216
# Family Buyer            22572
# Gamer                   12073
# Gift Buyer               9133
# Name: count, dtype: int64
#
# Tier
# Tier
# Tier-1    56726
# Tier-2    55570
# Tier-3    37704
# Name: count, dtype: int64
#
# City
# City
# Mumbai        9812
# Delhi         9112
# Bengaluru     8332
# Hyderabad     7648
# Chennai       6625
# Jaipur        6554
# Lucknow       5956
# Indore        5873
# Pune          5844
# Surat         5595
# Nagpur        5174
# Ahmedabad     5120
# Chandigarh    4767
# Bhopal        4392
# Kolkata       4233
# Coimbatore    4116
# Kochi         3721
# Patna         3466
# Varanasi      3458
# Gwalior       3363
# Siliguri      3232
# ...

# %%
text_cols = customers.select_dtypes(include="object").columns

customers[text_cols] = customers[text_cols].apply(lambda x: x.str.strip())
customers[text_cols] = customers[text_cols].apply(lambda x: x.str.replace(r"\s+", " ", regex=True))

# %%
customers.to_csv("Customer_Details_Clean.csv", index=False)

# %%
from google.colab import files
files.download("Customer_Details_Clean.csv")

# %%
delivery = pd.read_csv("Delivery_Partner_Data.csv")

# %%
delivery.head()
# Out:
#    DeliveryPartnerID PartnerName  HomeCity   Region    VehicleType  Rating  \
# 0               8001   Rider_001  Varanasi  Central  Electric Bike     4.5
# 1               8002   Rider_002    Indore    North            Van     4.8
# 2               8003   Rider_003  Ludhiana     West           Bike     4.7
# 3               8004   Rider_004     Delhi     East        Scooter     4.4
# 4               8005   Rider_005     Kochi    North  Electric Bike     4.6
#
#    ExperienceYears
# 0                2
# 1                9
# 2                8
# 3               11
# 4               10

# %%
delivery.shape
# Out:
# (180, 7)

# %%
delivery.columns.tolist()
# Out:
# ['DeliveryPartnerID',
#  'PartnerName',
#  'HomeCity',
#  'Region',
#  'VehicleType',
#  'Rating',
#  'ExperienceYears']

# %%
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DeliveryPartnerID  180 non-null    int64
#  1   PartnerName        180 non-null    object
#  2   HomeCity           180 non-null    object
#  3   Region             180 non-null    object
#  4   VehicleType        180 non-null    object
#  5   Rating             180 non-null    float64
#  6   ExperienceYears    180 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 10.0+ KB

# %%
delivery.describe(include="all")
# Out:
#         DeliveryPartnerID PartnerName HomeCity Region VehicleType      Rating  \
# count          180.000000         180      180    180         180  180.000000
# unique                NaN         180       35      5           4         NaN
# top                   NaN   Rider_001   Rajkot  North        Bike         NaN
# freq                  NaN           1       10     52          90         NaN
# mean          8090.500000         NaN      NaN    NaN         NaN    4.280000
# std             52.105662         NaN      NaN    NaN         NaN    0.363164
# min           8001.000000         NaN      NaN    NaN         NaN    3.600000
# 25%           8045.750000         NaN      NaN    NaN         NaN    4.000000
# 50%           8090.500000         NaN      NaN    NaN         NaN    4.300000
# 75%           8135.250000         NaN      NaN    NaN         NaN    4.600000
# max           8180.000000         NaN      NaN    NaN         NaN    4.900000
#
#         ExperienceYears
# ...

# %%
delivery.isnull().sum()
# Out:
# DeliveryPartnerID    0
# PartnerName          0
# HomeCity             0
# Region               0
# VehicleType          0
# Rating               0
# ExperienceYears      0
# dtype: int64

# %%
delivery.duplicated().sum()
# Out:
# np.int64(0)

# %%
delivery["DeliveryPartnerID"].nunique()
# Out:
# 180

# %%
delivery["Rating"].describe()
# Out:
# count    180.000000
# mean       4.280000
# std        0.363164
# min        3.600000
# 25%        4.000000
# 50%        4.300000
# 75%        4.600000
# max        4.900000
# Name: Rating, dtype: float64

# %%
delivery[delivery["Rating"] < 1]
# Out:
# Empty DataFrame
# Columns: [DeliveryPartnerID, PartnerName, HomeCity, Region, VehicleType, Rating, ExperienceYears]
# Index: []

# %%
delivery[delivery["ExperienceYears"] < 0]
# Out:
# Empty DataFrame
# Columns: [DeliveryPartnerID, PartnerName, HomeCity, Region, VehicleType, Rating, ExperienceYears]
# Index: []

# %%
text_cols = delivery.select_dtypes(include="object").columns

for col in text_cols:
    print(f"\n{col}")
    print(delivery[col].value_counts())
# Out:
# PartnerName
# PartnerName
# Rider_001    1
# Rider_002    1
# Rider_003    1
# Rider_004    1
# Rider_005    1
#             ..
# Rider_176    1
# Rider_177    1
# Rider_178    1
# Rider_179    1
# Rider_180    1
# Name: count, Length: 180, dtype: int64
#
# HomeCity
# HomeCity
# Rajkot        10
# Raipur         9
# Jaipur         8
# Jodhpur        7
# Asansol        7
# Indore         7
# Kochi          7
# Dehradun       7
# Mumbai         7
# Bareilly       7
# Ludhiana       6
# Surat          6
# Trichy         6
# Ahmedabad      6
# Bhopal         6
# Chandigarh     5
# Pune           5
# Gwalior        5
# Kolkata        5
# Patna          5
# Chennai        5
# Varanasi       4
# Siliguri       4
# Dhanbad        4
# Bengaluru      4
# Jabalpur       4
# Vadodara       4
# Mysuru         4
# Agra           3
# Hyderabad      3
# Lucknow        3
# Nagpur         2
# Kota           2
# Coimbatore     2
# Delhi          1
# Name: count, dtype: int64
#
# Region
# Region
# ...

# %%
delivery.to_csv("Delivery_Partner_Data_Clean.csv", index=False)

# %%
from google.colab import files
files.download("Delivery_Partner_Data_Clean.csv")

# %%
products = pd.read_csv("Product_Details.csv")

# %%
products.head()
# Out:
#    ProductID Brand               Category SubCategory            ProductName  \
# 0       1001  boAt  True Wireless Earbuds    Airdopes      boAt Airdopes 141
# 1       1002  boAt  True Wireless Earbuds    Airdopes      boAt Airdopes 161
# 2       1003  boAt  True Wireless Earbuds    Airdopes      boAt Airdopes 131
# 3       1004  boAt  True Wireless Earbuds    Airdopes  boAt Airdopes 181 Pro
# 4       1005  boAt  True Wireless Earbuds    Airdopes  boAt Airdopes 311 Pro
#
#    HeroFlag  LaunchYear     MRP  CostPrice  PopularityWeight DemandCluster
# 0         1        2024  9900.0    4445.96          0.138664          Hero
# 1         1        2025  6470.0    3185.78          0.061200          Hero
# 2         1        2025  1490.0     770.25          0.037928          Hero
# 3         1        2023  9050.0    3979.68          0.027011          Hero
# 4         0        2022  7670.0    3975.72          0.005931          Core

# %%
products.shape
# Out:
# (106, 11)

# %%
products.columns.tolist()
# Out:
# ['ProductID',
#  'Brand',
#  'Category',
#  'SubCategory',
#  'ProductName',
#  'HeroFlag',
#  'LaunchYear',
#  'MRP',
#  'CostPrice',
#  'PopularityWeight',
#  'DemandCluster']

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ProductID         106 non-null    int64
#  1   Brand             106 non-null    object
#  2   Category          106 non-null    object
#  3   SubCategory       106 non-null    object
#  4   ProductName       106 non-null    object
#  5   HeroFlag          106 non-null    int64
#  6   LaunchYear        106 non-null    int64
#  7   MRP               106 non-null    float64
#  8   CostPrice         106 non-null    float64
#  9   PopularityWeight  106 non-null    float64
#  10  DemandCluster     106 non-null    object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 9.2+ KB

# %%
products.describe(include="all")
# Out:
#           ProductID Brand               Category SubCategory  \
# count    106.000000   106                    106         106
# unique          NaN     1                     13          13
# top             NaN  boAt  True Wireless Earbuds    Airdopes
# freq            NaN   106                     28          28
# mean    1053.500000   NaN                    NaN         NaN
# std       30.743563   NaN                    NaN         NaN
# min     1001.000000   NaN                    NaN         NaN
# 25%     1027.250000   NaN                    NaN         NaN
# 50%     1053.500000   NaN                    NaN         NaN
# 75%     1079.750000   NaN                    NaN         NaN
# max     1106.000000   NaN                    NaN         NaN
#
#                  ProductName    HeroFlag   LaunchYear           MRP  \
# count                    106  106.000000   106.000000    106.000000
# unique                   105         NaN          NaN           NaN
# ...

# %%
products.isnull().sum()
# Out:
# ProductID           0
# Brand               0
# Category            0
# SubCategory         0
# ProductName         0
# HeroFlag            0
# LaunchYear          0
# MRP                 0
# CostPrice           0
# PopularityWeight    0
# DemandCluster       0
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products["ProductID"].nunique()
# Out:
# 106

# %%
products.apply(lambda x: x.astype(str).str.strip().eq("").sum())
# Out:
# ProductID           0
# Brand               0
# Category            0
# SubCategory         0
# ProductName         0
# HeroFlag            0
# LaunchYear          0
# MRP                 0
# CostPrice           0
# PopularityWeight    0
# DemandCluster       0
# dtype: int64

# %%
text_cols = products.select_dtypes(include="object").columns

products[text_cols] = products[text_cols].apply(
    lambda x: x.str.strip()
)

products[text_cols] = products[text_cols].apply(
    lambda x: x.str.replace(r"\s+", " ", regex=True)
)

# %%
text_cols = products.select_dtypes(include="object").columns

for col in text_cols:
    print(f"\n{col}")
    print(products[col].value_counts())
# Out:
# Brand
# Brand
# boAt    106
# Name: count, dtype: int64
#
# Category
# Category
# True Wireless Earbuds    28
# Neckbands                14
# Smart Watches            14
# Headphones               10
# Wireless Speakers        10
# Soundbars                 6
# Power Banks               5
# Wired Earphones           5
# Gaming Headphones         4
# Chargers & Cables         4
# Party Speakers            2
# Projectors                2
# Dashcams                  2
# Name: count, dtype: int64
#
# SubCategory
# SubCategory
# Airdopes                 28
# Neckbands                14
# Wave / Lunar / Ultima    14
# Rockerz                  10
# Stone                    10
# Soundbars                 6
# Energyshroom              5
# Bassheads                 5
# Gaming Rockerz            4
# Accessories               4
# PartyPal                  2
# Cinehead                  2
# Drive                     2
# Name: count, dtype: int64
#
# ProductName
# ProductName
# ...

# %%
products[products["ProductName"] == "boAt Rockerz 650 Pro"]
# Out:
#     ProductID Brand    Category SubCategory           ProductName  HeroFlag  \
# 33       1034  boAt   Neckbands   Neckbands  boAt Rockerz 650 Pro         0
# 58       1059  boAt  Headphones     Rockerz  boAt Rockerz 650 Pro         1
#
#     LaunchYear     MRP  CostPrice  PopularityWeight DemandCluster
# 33        2021  2590.0    1152.18          0.002360          Core
# 58        2023  5910.0    2927.52          0.010261          Hero

# %%
products[products["CostPrice"] > products["MRP"]]
# Out:
# Empty DataFrame
# Columns: [ProductID, Brand, Category, SubCategory, ProductName, HeroFlag, LaunchYear, MRP, CostPrice, PopularityWeight, DemandCluster]
# Index: []

# %%
products["Margin"] = products["MRP"] - products["CostPrice"]
products["Margin"].describe()
# Out:
# count     106.000000
# mean     2670.868396
# std      1800.041120
# min       354.700000
# 25%      1418.265000
# 50%      2427.685000
# 75%      3312.990000
# max      9479.550000
# Name: Margin, dtype: float64

# %%
products[products["Margin"] < 0]
# Out:
# Empty DataFrame
# Columns: [ProductID, Brand, Category, SubCategory, ProductName, HeroFlag, LaunchYear, MRP, CostPrice, PopularityWeight, DemandCluster, Margin]
# Index: []

# %%
products["HeroFlag"].value_counts()
# Out:
# HeroFlag
# 0    60
# 1    46
# Name: count, dtype: int64

# %%
products["LaunchYear"].value_counts().sort_index()
# Out:
# LaunchYear
# 2021     6
# 2022    20
# 2023    35
# 2024    27
# 2025    18
# Name: count, dtype: int64

# %%
products[products["PopularityWeight"] < 0]
# Out:
# Empty DataFrame
# Columns: [ProductID, Brand, Category, SubCategory, ProductName, HeroFlag, LaunchYear, MRP, CostPrice, PopularityWeight, DemandCluster, Margin]
# Index: []

# %%
products.to_csv("Product_Details_Clean.csv", index=False)

# %%
from google.colab import files
files.download("Product_Details_Clean.csv")

# %%
Saleschannel = pd.read_csv("Sales_Channel.csv")

# %%
Saleschannel.head()
# Out:
#    ChannelID            ChannelName         ChannelType ChannelScope  \
# 0          1           Amazon India  Online Marketplace       Online
# 1          2               Flipkart  Online Marketplace       Online
# 2          3  boAt Official Website                 D2C       Online
# 3          4                  Croma      Offline Retail      Offline
# 4          5       Reliance Digital      Offline Retail      Offline
#
#   RegionScope  BaseShare
# 0    National       0.34
# 1    National       0.28
# 2    National       0.12
# 3  Multi-city       0.09
# 4  Multi-city       0.07

# %%
Saleschannel.shape
# Out:
# (7, 6)

# %%
Saleschannel.columns.tolist()
# Out:
# ['ChannelID',
#  'ChannelName',
#  'ChannelType',
#  'ChannelScope',
#  'RegionScope',
#  'BaseShare']

# %%
Saleschannel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ChannelID     7 non-null      int64
#  1   ChannelName   7 non-null      object
#  2   ChannelType   7 non-null      object
#  3   ChannelScope  7 non-null      object
#  4   RegionScope   7 non-null      object
#  5   BaseShare     7 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 468.0+ bytes

# %%
Saleschannel.describe(include="all")
# Out:
#         ChannelID   ChannelName     ChannelType ChannelScope RegionScope  \
# count    7.000000             7               7            7           7
# unique        NaN             7               3            2           3
# top           NaN  Amazon India  Offline Retail      Offline    National
# freq          NaN             1               4            4           3
# mean     4.000000           NaN             NaN          NaN         NaN
# std      2.160247           NaN             NaN          NaN         NaN
# min      1.000000           NaN             NaN          NaN         NaN
# 25%      2.500000           NaN             NaN          NaN         NaN
# 50%      4.000000           NaN             NaN          NaN         NaN
# 75%      5.500000           NaN             NaN          NaN         NaN
# max      7.000000           NaN             NaN          NaN         NaN
#
#         BaseShare
# count    7.000000
# unique        NaN
# top           NaN
# ...

# %%
Saleschannel.isnull().sum()
# Out:
# ChannelID       0
# ChannelName     0
# ChannelType     0
# ChannelScope    0
# RegionScope     0
# BaseShare       0
# dtype: int64

# %%
Saleschannel.duplicated().sum()
# Out:
# np.int64(0)

# %%
Saleschannel.apply(lambda x: x.astype(str).str.strip().eq("").sum())
# Out:
# ChannelID       0
# ChannelName     0
# ChannelType     0
# ChannelScope    0
# RegionScope     0
# BaseShare       0
# dtype: int64

# %%
Saleschannel["ChannelID"].nunique()
# Out:
# 7

# %%
text_cols = Saleschannel.select_dtypes(include="object").columns

Saleschannel[text_cols] = Saleschannel[text_cols].apply(
    lambda x: x.str.strip()
)

Saleschannel[text_cols] = Saleschannel[text_cols].apply(
    lambda x: x.str.replace(r"\s+", " ", regex=True)
)

# %%
text_cols = Saleschannel.select_dtypes(include="object").columns

for col in text_cols:
    print(f"\n{col}")
    print(Saleschannel[col].value_counts())
# Out:
# ChannelName
# ChannelName
# Amazon India                1
# Flipkart                    1
# boAt Official Website       1
# Croma                       1
# Reliance Digital            1
# Vijay Sales                 1
# Local Multi-brand Retail    1
# Name: count, dtype: int64
#
# ChannelType
# ChannelType
# Offline Retail        4
# Online Marketplace    2
# D2C                   1
# Name: count, dtype: int64
#
# ChannelScope
# ChannelScope
# Offline    4
# Online     3
# Name: count, dtype: int64
#
# RegionScope
# RegionScope
# National      3
# Multi-city    3
# Regional      1
# Name: count, dtype: int64

# %%
Saleschannel.to_csv("Sales_Channel_Clean.csv", index=False)

# %%
from google.colab import files
files.download("Sales_Channel_Clean.csv")

# %%
sales = pd.read_csv("Sales_Data.csv")
# Out:
# /tmp/ipykernel_1149/774855261.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv("Sales_Data.csv")

# %%
sales.head()
# Out:
#    SalesID   OrderDate  OrderHour  CustomerID  ProductID  ChannelID  \
# 0        1  01-01-2023         20      550151       1104          4
# 1        2  01-01-2023         17      619093       1046          4
# 2        3  01-01-2023         16      562641       1046          1
# 3        4  01-01-2023         17      583589       1029          2
# 4        5  01-01-2023          8      607405       1031          1
#
#    DeliveryPartnerID  Quantity  GrossMRPValue  DiscountPct  ...  DeliveryDays  \
# 0               8129         1           1140       0.3689  ...             2
# 1               8174         2          21500       0.4150  ...             0
# 2               8106         1          10750       0.5633  ...             3
# 3               8159         1           2010       0.6133  ...             3
# 4               8082         1           1160       0.4518  ...             2
#
#    CustomerTier       CustomerSegment  CityTier  ChannelType  \
# ...

# %%
sales.shape
# Out:
# (975000, 32)

# %%
sales.columns.tolist()
# Out:
# ['SalesID',
#  'OrderDate',
#  'OrderHour',
#  'CustomerID',
#  'ProductID',
#  'ChannelID',
#  'DeliveryPartnerID',
#  'Quantity',
#  'GrossMRPValue',
#  'DiscountPct',
#  'DiscountAmount',
#  'SellingPrice',
#  'NetSales',
#  'GSTRate',
#  'GSTAmount',
#  'COGS',
#  'ShippingCost',
#  'Profit',
#  'PaymentMethod',
#  'OrderStatus',
#  'CancellationReason',
#  'ReturnReason',
#  'DeliveryDays',
#  'CustomerTier',
#  'CustomerSegment',
#  'CityTier',
#  'ChannelType',
#  'IsFestivalPeriod',
#  'FestivalName',
#  'IsWeekend',
#  'ProductCategory',
#  'HeroFlag']

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975000 entries, 0 to 974999
# Data columns (total 32 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   SalesID             975000 non-null  int64
#  1   OrderDate           975000 non-null  object
#  2   OrderHour           975000 non-null  int64
#  3   CustomerID          975000 non-null  int64
#  4   ProductID           975000 non-null  int64
#  5   ChannelID           975000 non-null  int64
#  6   DeliveryPartnerID   975000 non-null  int64
#  7   Quantity            975000 non-null  int64
#  8   GrossMRPValue       975000 non-null  int64
#  9   DiscountPct         975000 non-null  float64
#  10  DiscountAmount      975000 non-null  float64
#  11  SellingPrice        975000 non-null  float64
#  12  NetSales            975000 non-null  float64
#  13  GSTRate             975000 non-null  int64
#  14  GSTAmount           975000 non-null  float64
# ...

# %%
sales.describe(include="all")
# Out:
#               SalesID   OrderDate      OrderHour     CustomerID  \
# count   975000.000000      975000  975000.000000  975000.000000
# unique            NaN         731            NaN            NaN
# top               NaN  11-11-2023            NaN            NaN
# freq              NaN        2031            NaN            NaN
# mean    487500.500000         NaN      14.057422  575087.759241
# std     281458.400569         NaN       4.953023   43280.292318
# min          1.000000         NaN       0.000000  500001.000000
# 25%     243750.750000         NaN      10.000000  537577.000000
# 50%     487500.500000         NaN      14.000000  575104.500000
# 75%     731250.250000         NaN      18.000000  612614.250000
# max     975000.000000         NaN      23.000000  650000.000000
#
#             ProductID      ChannelID  DeliveryPartnerID       Quantity  \
# count   975000.000000  975000.000000      975000.000000  975000.000000
# ...

# %%
sales.isnull().sum()
# Out:
# SalesID                    0
# OrderDate                  0
# OrderHour                  0
# CustomerID                 0
# ProductID                  0
# ChannelID                  0
# DeliveryPartnerID          0
# Quantity                   0
# GrossMRPValue              0
# DiscountPct                0
# DiscountAmount             0
# SellingPrice               0
# NetSales                   0
# GSTRate                    0
# GSTAmount                  0
# COGS                       0
# ShippingCost               0
# Profit                     0
# PaymentMethod              0
# OrderStatus                0
# CancellationReason    959215
# ReturnReason          929605
# DeliveryDays               0
# CustomerTier               0
# CustomerSegment            0
# CityTier                   0
# ChannelType                0
# IsFestivalPeriod           0
# FestivalName          558942
# IsWeekend                  0
# ProductCategory            0
# HeroFlag                   0
# ...

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales.apply(lambda x: x.astype(str).str.strip().eq("").sum())
# Out:
# SalesID               0
# OrderDate             0
# OrderHour             0
# CustomerID            0
# ProductID             0
# ChannelID             0
# DeliveryPartnerID     0
# Quantity              0
# GrossMRPValue         0
# DiscountPct           0
# DiscountAmount        0
# SellingPrice          0
# NetSales              0
# GSTRate               0
# GSTAmount             0
# COGS                  0
# ShippingCost          0
# Profit                0
# PaymentMethod         0
# OrderStatus           0
# CancellationReason    0
# ReturnReason          0
# DeliveryDays          0
# CustomerTier          0
# CustomerSegment       0
# CityTier              0
# ChannelType           0
# IsFestivalPeriod      0
# FestivalName          0
# IsWeekend             0
# ProductCategory       0
# HeroFlag              0
# dtype: int64

# %%
sales["SalesID"].nunique()
# Out:
# 975000

# %%
sales["OrderDate"] = pd.to_datetime(
    sales["OrderDate"],
    dayfirst=True
)

# %%
sales["OrderDate"].describe()
# Out:
# count                           975000
# mean     2024-01-10 13:38:19.923692288
# min                2023-01-01 00:00:00
# 25%                2023-07-20 00:00:00
# 50%                2024-01-01 00:00:00
# 75%                2024-07-19 00:00:00
# max                2024-12-31 00:00:00
# Name: OrderDate, dtype: object

# %%
sales["Quantity"].describe()
# Out:
# count    975000.000000
# mean          1.123444
# std           0.417589
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
# Name: Quantity, dtype: float64

# %%
sales[sales["Quantity"] <= 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales["DiscountPct"].describe()
# Out:
# count    975000.000000
# mean          0.409372
# std           0.149571
# min           0.040000
# 25%           0.303600
# 50%           0.408400
# 75%           0.514900
# max           0.780000
# Name: DiscountPct, dtype: float64

# %%
sales[
    (sales["DiscountPct"] < 0) |
    (sales["DiscountPct"] > 1)
]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["GrossMRPValue"] <= 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["SellingPrice"] <= 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["NetSales"] <= 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales["GSTRate"].value_counts()
# Out:
# GSTRate
# 18    975000
# Name: count, dtype: int64

# %%
sales["ShippingCost"].describe()
# Out:
# count    975000.000000
# mean         55.031713
# std          17.661132
# min          12.000000
# 25%          43.830000
# 50%          56.930000
# 75%          67.650000
# max         113.940000
# Name: ShippingCost, dtype: float64

# %%
sales[
    sales["ShippingCost"] < 0
]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales["Profit"].describe()
# Out:
# count    975000.000000
# mean        598.371936
# std        1530.006718
# min      -42347.110000
# 25%         -72.120000
# 50%         339.035000
# 75%        1209.712500
# max       28087.350000
# Name: Profit, dtype: float64

# %%
sales[
    sales["Profit"] < 0
]
# Out:
#         SalesID  OrderDate  OrderHour  CustomerID  ProductID  ChannelID  \
# 2             3 2023-01-01         16      562641       1046          1
# 3             4 2023-01-01         17      583589       1029          2
# 6             7 2023-01-01         23      578471       1043          1
# 7             8 2023-01-01         13      596487       1103          2
# 8             9 2023-01-01         21      578525       1096          1
# ...         ...        ...        ...         ...        ...        ...
# 974990   974991 2024-12-31         19      544205       1067          2
# 974991   974992 2024-12-31         17      575973       1002          1
# 974993   974994 2024-12-31          8      550980       1088          2
# 974998   974999 2024-12-31         12      505714       1067          1
# 974999   975000 2024-12-31         21      609496       1098          1
#
#         DeliveryPartnerID  Quantity  GrossMRPValue  DiscountPct  ...  \
# ...

# %%
pd.crosstab(
    sales["IsFestivalPeriod"],
    sales["FestivalName"],
    dropna=False
)
# Out:
# FestivalName      Big Festive Sale  Holi Sale  Independence Day Sale  \
# IsFestivalPeriod
# 0                                0          0                      0
# 1                           176351      27705                  20144
#
# FestivalName      Monsoon Deals  New Year Sale  Raksha Bandhan Sale  \
# IsFestivalPeriod
# 0                             0              0                    0
# 1                         39950          21025                26135
#
# FestivalName      Republic Day Sale  Summer Sale  Year End Sale     NaN
# IsFestivalPeriod
# 0                                 0            0              0  558942
# 1                             24262        42307          38179       0

# %%
pd.crosstab(
    sales["OrderStatus"],
    sales["CancellationReason"],
    dropna=False
)
# Out:
# CancellationReason  Address issue  COD not confirmed  Customer cancelled  \
# OrderStatus
# Cancelled                    3913               2928                1069
# Delivered                       0                  0                   0
# Returned                        0                  0                   0
#
# CancellationReason  Customer changed mind  Customer unreachable  \
# OrderStatus
# Cancelled                             580                  2382
# Delivered                               0                     0
# Returned                                0                     0
#
# CancellationReason  Payment failed  Stockout  Store stockout     NaN
# OrderStatus
# Cancelled                     1559      2337            1017       0
# Delivered                        0         0               0  913820
# Returned                         0         0               0   45395

# %%
pd.crosstab(
    sales["OrderStatus"],
    sales["ReturnReason"],
    dropna=False
)
# Out:
# ReturnReason  App sync issue  Battery drain  Cable defect  Capacity mismatch  \
# OrderStatus
# Cancelled                  0              0             0                  0
# Delivered                  0              0             0                  0
# Returned                2073           1422           229                287
#
# ReturnReason  Changed mind  Charging defect  Charging issue  Comfort issue  \
# OrderStatus
# Cancelled                0                0               0              0
# Delivered                0                0               0              0
# Returned             11390             4431             272           1365
#
# ReturnReason  Compatibility issue  Connectivity issue  ...  Recording issue  \
# OrderStatus                                            ...
# Cancelled                       0                   0  ...                0
# Delivered                       0                   0  ...                0
# ...

# %%
sales["SalesID"].nunique()
# Out:
# 975000

# %%
sales["Quantity"].describe()
# Out:
# count    975000.000000
# mean          1.123444
# std           0.417589
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
# Name: Quantity, dtype: float64

# %%
sales[sales["Quantity"] <= 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales["DiscountPct"].describe()
# Out:
# count    975000.000000
# mean          0.409372
# std           0.149571
# min           0.040000
# 25%           0.303600
# 50%           0.408400
# 75%           0.514900
# max           0.780000
# Name: DiscountPct, dtype: float64

# %%
sales[(sales["DiscountPct"] < 0) | (sales["DiscountPct"] > 1)]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales["GSTRate"].value_counts()
# Out:
# GSTRate
# 18    975000
# Name: count, dtype: int64

# %%
sales["Profit"].describe()
# Out:
# count    975000.000000
# mean        598.371936
# std        1530.006718
# min      -42347.110000
# 25%         -72.120000
# 50%         339.035000
# 75%        1209.712500
# max       28087.350000
# Name: Profit, dtype: float64

# %%
# Number of loss-making orders
(sales["Profit"] < 0).sum()
# Out:
# np.int64(283173)

# %%
# Percentage of loss-making orders
((sales["Profit"] < 0).mean() * 100).round(2)
# Out:
# np.float64(29.04)

# %%
sales[sales["SellingPrice"] > sales["GrossMRPValue"]]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["DiscountAmount"] < 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["ShippingCost"] < 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["COGS"] < 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales[sales["GSTAmount"] < 0]
# Out:
# Empty DataFrame
# Columns: [SalesID, OrderDate, OrderHour, CustomerID, ProductID, ChannelID, DeliveryPartnerID, Quantity, GrossMRPValue, DiscountPct, DiscountAmount, SellingPrice, NetSales, GSTRate, GSTAmount, COGS, ShippingCost, Profit, PaymentMethod, OrderStatus, CancellationReason, ReturnReason, DeliveryDays, CustomerTier, CustomerSegment, CityTier, ChannelType, IsFestivalPeriod, FestivalName, IsWeekend, ProductCategory, HeroFlag]
# Index: []
#
# [0 rows x 32 columns]

# %%
sales.to_csv("Sales_Data_Clean.csv", index=False)

# %%
from google.colab import files
files.download("Sales_Data_Clean.csv")
